# %% [markdown]
# # Stage 1: Task 0 Cache
#
# Notebook này load manifest + latent/noise cache từ stage 0, rồi tạo `V64`, descriptor cache, preview cache và metadata của Task 0.

# %%
import pathlib, sys
ROOT = pathlib.Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print(ROOT)

# %%
from kaggle_sit_protocol import ProtocolConfig, run_task0_stage

cfg = ProtocolConfig.from_kaggle_defaults()
# Optional overrides:
# cfg.checkpoint_path = '/kaggle/input/<your-model-dataset>/SiT-XL-2-256x256.pt'
# cfg.vae_model = '/kaggle/input/<your-vae-dataset>/sd-vae-ft-ema'
cfg.ensure_directories()
result = run_task0_stage(cfg)
result
