# %% [markdown]
# # Stage 2: Tasks 1 to 10
#
# Notebook này load runtime từ cache gọn và chạy tuần tự Task 1-10 của protocol.

# %%
import pathlib, sys
ROOT = pathlib.Path.cwd().resolve()
if str(ROOT) not in sys.path:
    sys.path.insert(0, str(ROOT))
print(ROOT)

# %%
from kaggle_sit_protocol import ProtocolConfig, run_analysis_stage

cfg = ProtocolConfig.from_kaggle_defaults()
# Optional overrides:
# cfg.checkpoint_path = '/kaggle/input/<your-model-dataset>/SiT-XL-2-256x256.pt'
# cfg.vae_model = '/kaggle/input/<your-vae-dataset>/sd-vae-ft-ema'
cfg.ensure_directories()
result = run_analysis_stage(cfg)
result
